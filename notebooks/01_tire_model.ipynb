# %% [markdown]
# # Pacejka MF5.0 Tire Model — Hoosier 16.0x7.5-10 R20
#
# Validates the tire model force curves and prints key metrics.

# %%
from src.tire import validate
validate()

# %% [markdown]
# ## Expected Output
#
# - Peak lateral friction coefficient: ~1.99
# - Peak slip angle: ~5.8°
# - Cornering stiffness at 500N: ~20.8 kN/rad
# - Force curves saved to `results/validation/tire_curves.png`
