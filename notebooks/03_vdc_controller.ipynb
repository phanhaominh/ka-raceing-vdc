# %% [markdown]
# # VDC Controller Test\n\nTests torque vectoring, traction control, and brake blending in a corner-entry maneuver.

# %%
from src.controller import vdc_test\nvdc_test()

# %% [markdown]
# ## Expected Behavior\n\n- Torque split: outside wheels receive higher torque during cornering\n- Yaw rate tracks kinematic target\n- Slip ratios stay below TC threshold at moderate throttle\n- Brake blending engages with regen priority\n- Trace saved to `results/validation/vdc_test.png`
