# %% [markdown]
# # KIT25e Vehicle Model Validation\n\nValidates the 3-DOF vehicle model against FSG 2025 competition data.\nTargets: Skidpad 5.14s | Acceleration 3.57s

# %%
from src.vehicle import skidpad_test\nskidpad_test()

# %%
from src.vehicle import acceleration_test\nacceleration_test()

# %% [markdown]
# ## Expected Results\n\n- Skidpad: ~5.20s (actual: 5.14s, +1.2%)\n- Acceleration: ~3.76s (actual: 3.57s, +5.3%)\n- Traces saved to `results/validation/`
